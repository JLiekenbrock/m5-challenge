# %%
import pandas as pd
import numpy as np
import importlib
from sklearn.metrics import root_mean_squared_error

import utils

importlib.reload(utils)

from utils import load_data

# %%
def reduce_mem_usage(df):
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))

    return df

# %%
data = load_data(prepare=False)
data = data.sort_values(by=["id","day_num"])
data.loc[:, 'lag'] = data.groupby('id')['value'].shift(1)

# %%
data[data["lag"].isna()]["day_num"].describe()
# Out:
# count    30490.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
# Name: day_num, dtype: float64

# %%
data.groupby("id").size().describe()
# Out:
# count    30490.0
# mean      1941.0
# std          0.0
# min       1941.0
# 25%       1941.0
# 50%       1941.0
# 75%       1941.0
# max       1941.0
# dtype: float64

# %%
data["train"] = data["day_num"]<=1913

# %%
data.head(10)
# Out:
#                                  id      item_id  dept_id cat_id store_id  \
# 1612    FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 32102   FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 62592   FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 93082   FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 123572  FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 154062  FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 184552  FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 215042  FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 245532  FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 276022  FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
#
#        state_id     d  value  day_num       date  ...  year event_name_1  \
# 1612         CA   d_1      3        1 2011-01-29  ...  2011         None
# 32102        CA   d_2      0        2 2011-01-30  ...  2011         None
# 62592        CA   d_3      0        3 2011-01-31  ...  2011         None
# 93082        CA   d_4      1        4 2011-02-01  ...  2011         None
# 123572       CA   d_5      4        5 2011-02-02  ...  2011         None
# 154062       CA   d_6      2        6 2011-02-03  ...  2011         None
# 184552       CA   d_7      0        7 2011-02-04  ...  2011         None
# 215042       CA   d_8      2        8 2011-02-05  ...  2011         None
# 245532       CA   d_9      0        9 2011-02-06  ...  2011    SuperBowl
# 276022       CA  d_10      0       10 2011-02-07  ...  2011         None
#
#         event_type_1  event_name_2  event_type_2 snap sell_price total_volume  \
# 1612            None          None          None    0        2.0          6.0
# 32102           None          None          None    0        2.0          0.0
# 62592           None          None          None    0        2.0          0.0
# 93082           None          None          None    1        2.0          2.0
# 123572          None          None          None    1        2.0          8.0
# 154062          None          None          None    1        2.0          4.0
# 184552          None          None          None    1        2.0          0.0
# 215042          None          None          None    1        2.0          4.0
# 245532      Sporting          None          None    1        2.0          0.0
# 276022          None          None          None    1        2.0          0.0
#
#        train  lag
# 1612    True  NaN
# 32102   True  3.0
# 62592   True  0.0
# 93082   True  0.0
# 123572  True  1.0
# 154062  True  4.0
# 184552  True  2.0
# 215042  True  0.0
# 245532  True  2.0
# 276022  True  0.0
#
# [10 rows x 24 columns]

# %%
data["events"] = data["event_name_1"].notna()+data["event_name_2"].notna()

# %%
data[["lag","value","events"]].corr()
# Out:
#              lag     value    events
# lag     1.000000  0.767991  0.006919
# value   0.767991  1.000000 -0.003660
# events  0.006919 -0.003660  1.000000

# %%
dummies = pd.get_dummies(data[["event_name_1","event_type_1","event_name_2","event_type_2"]])

dummie_columns = dummies.columns

# %%
data = pd.concat([data,dummies],axis=1)

# %%
del dummies

# %%
data['sell_price_filled'] = data.groupby('id')['sell_price'].ffill().bfill()

# %%
train = data[data['train']].dropna(subset="sell_price")
train = train[train["day_num"]>1]

test = data[~data['train']]

# %%
import category_encoders as ce

categories = ["event_name_1", "event_type_1", "event_name_2", "event_type_2", "cat_id", "state_id","wday","snap"]
target_enc = ce.TargetEncoder(cols=categories)
encoded_train = target_enc.fit_transform(train[categories], train['value'])
encoded_train = encoded_train.rename(columns=lambda col: f"{col}_encoded")

encoded_columns = encoded_train.columns

# %%
train = pd.concat([train,encoded_train],axis=1)

# %%
encoded_test = target_enc.fit_transform(test[categories], test['value'])
encoded_test = encoded_test.rename(columns=lambda col: f"{col}_encoded")

test = pd.concat([test,encoded_test],axis=1)

# %%
del encoded_train, encoded_test

# %%
features = list(encoded_columns)+["day_num", "wday", "month", "year", "snap", "lag", "sell_price"]

# %%
X_train = train[features]
y_train = train['value']


X_test = test[features]
y_test = test['value']

# %%
import lightgbm as lgb

# %%
gbm = lgb.LGBMRegressor(objective ='poisson' )

gbm.fit(X_train, y_train,
        eval_set=[(X_test, y_test)],
        eval_metric='l2'
        )
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 1.246942 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 690
# [LightGBM] [Info] Number of data points in the train set: 46017025, number of used features: 15
# [LightGBM] [Info] Start training from score 0.355521
# LGBMRegressor(objective='poisson')

# %%
from sklearn import linear_model
clf = linear_model.PoissonRegressor(max_iter=200)
clf.fit(X_train, y_train)
# Out:
# C:\Users\janli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_glm\glm.py:283: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# PoissonRegressor(max_iter=200)

# %%
clf.score(X_train, y_train)
# Out:
# 0.20320674610716738

# %%
train["id"].nunique()
# Out:
# 30490

# %%
def make_prediciton(regressor):
    predictions = []

    for day in test["day_num"].unique():
        # Combine the current lags and additional features
        t = test.loc[test["day_num"]==day,:]    
        
        # Make the prediction

        if type(regressor) == "lightgbm.sklearn.LGBMRegressor":
            next_pred = gbm.predict(X_train, num_iteration=gbm.best_iteration_)
        else:
            next_pred = regressor.predict(t[features])

        predictions.append(next_pred)

        if day < 1941:
            test.loc[ (test["day_num"]==day+1) ,"lag"] = next_pred

    print("Recursive predictions:", predictions)
    return( np.array(predictions).T.flatten())

# %%
test["fc_lin"] = make_prediciton(clf)
# Out:
# Recursive predictions: [array([1.69637782, 1.79922011, 1.69637782, ..., 0.70205049, 0.70205049,
#        0.70205049]), array([1.67746798, 1.68000837, 1.67746798, ..., 0.68414133, 0.68414133,
#        0.68414133]), array([1.61937001, 1.61943054, 1.61937001, ..., 0.66045628, 0.66045628,
#        0.66045628]), array([1.56332891, 1.56333031, 1.56332891, ..., 0.63792299, 0.63792299,
#        0.63792299]), array([1.51387005, 1.51387008, 1.51387005, ..., 0.61804574, 0.61804574,
#        0.61804574]), array([1.87055479, 1.87055479, 1.87055479, ..., 0.76399672, 0.76399672,
#        0.76399672]), array([1.86805731, 1.86805731, 1.86805731, ..., 0.73716585, 0.73716585,
#        0.73716585]), array([1.78832767, 1.78832767, 1.78832767, ..., 0.72789038, 0.72789038,
#        0.72789038]), array([1.7227754 , 1.7227754 , 1.7227754 , ..., 0.70193642, 0.70193642,
#        0.70193642]), array([1.6619672 , 1.6619672 , 1.6619672 , ..., 0.65666708, 0.65666708,
#        0.65666708]), array([1.6032147 , 1.6032147 , 1.6032147 , ..., 0.65375218, 0.65375218,
#        0.65375218]), array([1.55356814, 1.55356814, 1.55356814, ..., 0.63402823, 0.63402823,
#        0.63402823]), array([1.91498464, 1.91498464, 1.91498464, ..., 0.75776656, 0.75776656,
#        0.75776656]), array([1.86201239, 1.86201239, 1.86201239, ..., 0.75758822, 0.75758822,
#        0.75758822]), array([1.78573313, 1.78573313, 1.78573313, ..., 0.72711746, 0.72711746,
#        0.72711746]), array([1.72036331, 1.72036331, 1.72036331, ..., 0.67936248, 0.67936248,
#        0.67936248]), array([1.60848033, 1.60848033, 1.60848033, ..., 0.67640755, 0.67640755,
#        0.67640755]), array([1.55158764, 1.55158764, 1.55158764, ..., 0.65352936, 0.65352936,
#        0.65352936]), array([1.50248141, 1.50248141, 1.50248141, ..., 0.61364315, 0.61364315,
#        0.61364315]), array([1.852028  , 1.852028  , 1.852028  , ..., 0.78057138, 0.78057138,
#        0.78057138]), array([1.79943812, 1.79943812, 1.79943812, ..., 0.7563712 , 0.7563712 ,
#        0.7563712 ]), array([1.72673383, 1.72673383, 1.72673383, ..., 0.70372911, 0.70372911,
#        0.70372911]), array([1.66361129, 1.66361129, 1.66361129, ..., 0.67820374, 0.67820374,
#        0.67820374]), array([1.60494877, 1.60494877, 1.60494877, ..., 0.65465089, 0.65465089,
#        0.65465089]), array([1.54939387, 1.54939387, 1.54939387, ..., 0.63231689, 0.63231689,
#        0.63231689]), array([1.5003866 , 1.5003866 , 1.5003866 , ..., 0.61261613, 0.61261613,
#        0.61261613]), array([1.84944853, 1.84944853, 1.84944853, ..., 0.75546575, 0.75546575,
#        0.75546575]), array([1.79691909, 1.79691909, 1.79691909, ..., 0.7317846 , 0.7317846 ,
#        0.7317846 ])]

# %%
test["fc_gbm"] = make_prediciton(gbm)
# Out:
# Recursive predictions: [array([0.5966539 , 2.92796583, 0.5966539 , ..., 0.34367006, 0.34367006,
#        0.34367006]), array([1.15022544, 1.94083801, 1.15022544, ..., 0.63154029, 0.63154029,
#        0.63154029]), array([1.1603609 , 1.50652159, 1.1603609 , ..., 0.63548392, 0.63548392,
#        0.63548392]), array([1.1603609 , 1.50652159, 1.1603609 , ..., 0.63548392, 0.63548392,
#        0.63548392]), array([1.35621272, 1.79634885, 1.35621272, ..., 0.75118781, 0.75118781,
#        0.75118781]), array([1.47847183, 1.9303135 , 1.47847183, ..., 0.90683424, 0.90683424,
#        0.90683424]), array([1.43283688, 1.84013163, 1.43283688, ..., 0.8148436 , 0.8148436 ,
#        0.8148436 ]), array([1.36855604, 1.80601959, 1.36855604, ..., 0.75315241, 0.75315241,
#        0.75315241]), array([1.18146217, 1.56642825, 1.18146217, ..., 0.63685999, 0.63685999,
#        0.63685999]), array([1.1859428 , 1.58030176, 1.1859428 , ..., 0.63548392, 0.63548392,
#        0.63548392]), array([1.1859428 , 1.58030176, 1.1859428 , ..., 0.639318  , 0.639318  ,
#        0.639318  ]), array([1.36836805, 1.82105545, 1.36836805, ..., 0.75304896, 0.75304896,
#        0.75304896]), array([1.65397499, 2.21402779, 1.65397499, ..., 1.00890366, 1.00890366,
#        1.00890366]), array([1.96550647, 1.96550647, 1.96550647, ..., 0.84589069, 0.84589069,
#        0.84589069]), array([1.80601959, 1.80601959, 1.80601959, ..., 0.75315241, 0.75315241,
#        0.75315241]), array([1.56642825, 1.56642825, 1.56642825, ..., 0.63154029, 0.63154029,
#        0.63154029]), array([1.50652159, 1.50652159, 1.50652159, ..., 0.639318  , 0.639318  ,
#        0.639318  ]), array([1.50652159, 1.50652159, 1.50652159, ..., 0.639318  , 0.639318  ,
#        0.639318  ]), array([1.79634885, 1.79634885, 1.79634885, ..., 0.75118781, 0.75118781,
#        0.75118781]), array([2.21504728, 2.21504728, 2.21504728, ..., 1.00892635, 1.00892635,
#        1.00892635]), array([1.96341209, 1.96341209, 1.96341209, ..., 0.84589069, 0.84589069,
#        0.84589069]), array([1.77729463, 1.77729463, 1.77729463, ..., 0.74951037, 0.74951037,
#        0.74951037]), array([1.48586601, 1.48586601, 1.48586601, ..., 0.63154029, 0.63154029,
#        0.63154029]), array([1.1603609 , 1.1603609 , 1.1603609 , ..., 0.63548392, 0.63548392,
#        0.63548392]), array([1.1603609 , 1.1603609 , 1.1603609 , ..., 0.63548392, 0.63548392,
#        0.63548392]), array([1.35621272, 1.35621272, 1.35621272, ..., 0.75118781, 0.75118781,
#        0.75118781]), array([1.64488236, 1.64488236, 1.64488236, ..., 1.00890366, 1.00890366,
#        1.00890366]), array([1.96341209, 1.96341209, 1.96341209, ..., 0.84587167, 0.84587167,
#        0.84587167])]

# %%
test["fc_lin"].describe()
# Out:
# count    853720.000000
# mean          1.178480
# std           0.552837
# min           0.003305
# 25%           0.750488
# 50%           1.201842
# 75%           1.613466
# max          12.956938
# Name: fc_lin, dtype: float64

# %%
test["fc_gbm"].describe()
# Out:
# count    853720.000000
# mean          1.499840
# std           1.875776
# min           0.268423
# 25%           0.761277
# 50%           1.066078
# 75%           1.506522
# max         161.913563
# Name: fc_gbm, dtype: float64

# %%
root_mean_squared_error(test["value"],test["fc_lin"])
# Out:
# 3.5622449127451574

# %%
root_mean_squared_error(test["value"],test["fc_gbm"])
# Out:
# 3.117888245617378

# %%
weights = (
    train[train["day_num"]>(1914-28)]
        .groupby("id")["total_volume"]
        .sum()
)

# %%
weights = weights/weights.sum()

# %%
weights.sum()
# Out:
# 1.0

# %%
train["squared_diff"] = (train["value"] - train["lag"]) **2

mse_train = (
    train.groupby("id")["squared_diff"]
        .mean()
).rename("mse_train")

# %%
mse_train.describe()
# Out:
# count    30490.000000
# mean         7.873469
# std         50.214720
# min          0.025105
# 25%          0.678340
# 50%          1.660325
# 75%          4.230648
# max       4929.767782
# Name: mse_train, dtype: float64

# %%
test["squared_diff"] = (test["value"] - test["fc_gbm"])**2

mse_test = (
    test
        .groupby("id")["squared_diff"]
        .mean()
).rename("mse_test")

# %%
mse_test.describe()
# Out:
# count    30490.000000
# mean         9.721227
# std         69.153293
# min          0.255920
# 25%          0.668457
# 50%          1.314442
# 75%          3.209080
# max       3441.847522
# Name: mse_test, dtype: float64

# %%
t = (
    pd.concat([mse_test, mse_train, weights], axis=1)
)

# %%
result = (
    t["total_volume"] * np.sqrt( (t["mse_test"] / t["mse_train"]) )
).sum()

# %%
result
# Out:
# 1.1819592632263867

# %%
train.head()
# Out:
#                                  id      item_id  dept_id cat_id store_id  \
# 32102   FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 62592   FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 93082   FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 123572  FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 154062  FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
#
#        state_id    d  value  day_num       date  ...  sell_price_filled  \
# 32102        CA  d_2      0        2 2011-01-30  ...                2.0
# 62592        CA  d_3      0        3 2011-01-31  ...                2.0
# 93082        CA  d_4      1        4 2011-02-01  ...                2.0
# 123572       CA  d_5      4        5 2011-02-02  ...                2.0
# 154062       CA  d_6      2        6 2011-02-03  ...                2.0
#
#        event_name_1_encoded  event_type_1_encoded  event_name_2_encoded  \
# 32102              1.432388              1.432388              1.426622
# 62592              1.432388              1.432388              1.426622
# 93082              1.432388              1.432388              1.426622
# 123572             1.432388              1.432388              1.426622
# 154062             1.432388              1.432388              1.426622
#
#         event_type_2_encoded cat_id_encoded state_id_encoded wday_encoded  \
# 32102               1.426622       2.106858         1.573651     1.708244
# 62592               1.426622       2.106858         1.573651     1.365807
# 93082               1.426622       2.106858         1.573651     1.262531
# 123572              1.426622       2.106858         1.573651     1.247616
# 154062              1.426622       2.106858         1.573651     1.255723
#
#        snap_encoded  squared_diff
# 32102      1.368049           9.0
# 62592      1.368049           0.0
# 93082      1.547151           1.0
# 123572     1.547151           9.0
# 154062     1.547151           4.0
#
# [5 rows x 75 columns]
